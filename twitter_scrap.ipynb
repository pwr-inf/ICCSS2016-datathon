# %%
import tweeter_scrapp-light as ts
import requests
from string import Template

# %%
proxies = {'http': "socks5://gold.engine.kdm.wcss.pl:9050"}
proxies['https']=proxies['http']

headers_custom= {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

tweet_template=Template('https://mobile.twitter.com/$user/status/$tweet_id')
uri=tweet_template.substitute({'user':'realDonaldTrump','tweet_id':'744253170218524672'})
response=requests.get(uri,headers=headers_custom,proxies=proxies)

# %%
response=requests.get(uri,headers=headers_custom,proxies=proxies)
response
# Out:
# <Response [200]>

# %%
import os
import cPickle as pickle
path='tweets/realDonaldTrump'
data=list()
for filename in os.listdir(path):
     data.extend(pickle.load(open(path+'/'+filename,'rb')))
    2    
pickle.dump(data,open(path+'.p','wb'))

# %%
data[0]['responses']
# Out:
# [{'date': u'2016-06-09T00:49:23+0000',
#   'text': u".@realDonaldTrump You WON'T be OUR NEXT PRESIDENT",
#   'user': u'@realDrumpf'},
#  {'date': u'2016-06-09T00:49:27+0000',
#   'text': u"@realDonaldTrump  https://www.youtube.com/watch?v=1FJ6WYtLgbo \u2026 You're the President our country needs. We can't lose anymore! #VoteTrump pic.twitter.com/T2hUDY14L5",
#   'user': u'@NeilTurner_'},
#  {'date': u'2016-06-09T00:49:32+0000',
#   'text': u'@realDonaldTrump @nauthizjane bigot',
#   'user': u'@DavidADemarest'}]

# %%
d=map(lambda x: x.get('text',''),data)

# %%
print d
# Out:
# [u'"@nauthizjane: @realDonaldTrump Congratulations Mr. Trump."  Thank you!', u'MAKE AMERICA GREAT AGAIN!\n#AmericaFirst #Trump2016\n https://amp.twimg.com/v/8e763c35-d35d-4c6b-bf41-a527ab4cfb64 \u2026', u'I would have had many millions of votes more than Crooked Hillary Clinton except for the fact that I had 16 opponents, she had one!', u'Thank you New Mexico! #Trump2016\n https://www.facebook.com/DonaldTrump/posts/10157139384175725:0 \u2026 ', u'"@southpaw816: @SenSanders fans, greatest way to get even with her Highness - vote for @realDonaldTrump, at least you\'ll have a job.', u'"@sara_wejesa: @realDonaldTrump Great speach!!!!!!!"  Thanks!', u'Thank you Montana! #Trump2016\n https://www.facebook.com/DonaldTrump/posts/10157139281305725:0 \u2026 ', u'Thank you California! #Trump2016\n https://www.facebook.com/DonaldTrump/posts/10157139440985725:0 \u2026 ', u'Thank you South Dakota! #Trump2016\n https://www.facebook.com/DonaldTrump/posts/10157139363145725:0 \u2026 ', u'"@WolfStopper:
# ...

# %%
ts.get_tweet_details('717003103871115267','realDonaldTrump')
# Out:
# 717003103871115267
# {}

# %%
candidate=pickle.load(open('tweets/MartinOMalley.p','rb'))
len(candidate)
# Out:
# 3226

# %%
# Out:
# 3210
