# %%
import tweeter_follower_scrapp as tfs

# %%
tfs.get_all_followers('realDonaldTrump','tweeter_followers/trump/')
# Out:
# Getting all followers for realDonaldTrump
# current page:https://mobile.twitter.com/realDonaldTrump/followers
# NasimaNasima5
# JosephMagi
# DegomitaBoo
# redpillhk
# Mr_AmMaL2002
# DhaderHammad
# mcarrasco61
# sangam_biradar
# abby1312004
# papabenku420
# jpace6690
# gjdhdparts
# EddoL21
# RoseangleQ
# entjunicorn
# francis22278059
# kristinlewis71
# chithien10
# mariahgarcia381
# BISHNUDEVROY2
# next page:https://mobile.twitter.com/realDonaldTrump/followers?cursor=1537897854532353599
# current page:https://mobile.twitter.com/realDonaldTrump/followers?cursor=1537897854532353599
# accidental_puns
# OpuOpuraj
# billeo17
# gojko_che
# JoeComuniello29
# marisa_ercolani
# papichrissV

# %%
import os
import cPickle as pickle
path='tweeter_followers/trump/'
data=list()
for filename in os.listdir(path):
     data.extend(pickle.load(open(path+filename,'rb')))

# %%
data
# Out:
# [{'latest_tweets': [],
#   'tweets': u'0',
#   'user': u'NasimaNasima5',
#   'watchers': u'0',
#   'watching': u'84'},
#  {'latest_tweets': [],
#   'tweets': u'0',
#   'user': u'JosephMagi',
#   'watchers': u'0',
#   'watching': u'86'},
#  {'latest_tweets': [],
#   'tweets': u'0',
#   'user': u'DegomitaBoo',
#   'watchers': u'0',
#   'watching': u'22'},
#  {'latest_tweets': [{'date': u'\n4m\n',
#     'text': u'\n  Hello Twitter! #myfirstTweet\n\n'}],
#   'tweets': u'1',
#   'user': u'redpillhk',
#   'watchers': u'0',
#   'watching': u'21'},
#  {'latest_tweets': [],
#   'tweets': u'0',
#   'user': u'Mr_AmMaL2002',
#   'watchers': u'0',
#   'watching': u'101'},
#  {'latest_tweets': [],
#   'tweets': u'0',
#   'user': u'DhaderHammad',
#   'watchers': u'0',
#   'watching': u'16'},
#  {'latest_tweets': [],
#   'tweets': u'0',
#   'user': u'mcarrasco61',
#   'watchers': u'0',
#   'watching': u'99'},
#  {'latest_tweets': [{'date': u'\nJun 14\n', 'text': u'\n @Ryb143 welcome\n\n'},
# ...
